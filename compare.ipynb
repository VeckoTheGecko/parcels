# %%
# Use xarray to open `data-v4/nemo/field/*U*.nc`

from pathlib import Path

import xarray as xr

from parcels._datasets import utils
from parcels._datasets.structured.circulation_model import T,Z,Y,X

PATH = Path().parent / "data-v4"


def open_nemo() -> xr.Dataset:
    # xr openmfdataset concat dim is time_counter and combine is nested

    return xr.open_mfdataset(
        f"{PATH}/nemo/grid.nc",
        # concat_dim="time_counter",
        # combine="nested",
    )


reference = open_nemo()

# %%
reference.e1f.attrs
# Out:
# {}

# %%
print(reference)
print(reference.attrs)
# Out:
# <xarray.Dataset> Size: 1GB
# Dimensions:       (y: 3059, x: 4322, z: 50, t: 1)
# Dimensions without coordinates: y, x, z, t
# Data variables: (12/21)
#     nav_lon       (y, x) float32 53MB dask.array<chunksize=(3059, 4322), meta=np.ndarray>
#     nav_lat       (y, x) float32 53MB dask.array<chunksize=(3059, 4322), meta=np.ndarray>
#     nav_lev       (z) float32 200B dask.array<chunksize=(50,), meta=np.ndarray>
#     time_counter  (t) float64 8B dask.array<chunksize=(1,), meta=np.ndarray>
#     glamt         (t, y, x) float32 53MB dask.array<chunksize=(1, 3059, 4322), meta=np.ndarray>
#     glamu         (t, y, x) float32 53MB dask.array<chunksize=(1, 3059, 4322), meta=np.ndarray>
#     ...            ...
#     e1f           (t, y, x) float64 106MB dask.array<chunksize=(1, 3059, 4322), meta=np.ndarray>
#     e2t           (t, y, x) float64 106MB dask.array<chunksize=(1, 3059, 4322), meta=np.ndarray>
# ...

# %%
print("\nDataset Attributes:")
print(reference.attrs)

print("\nCoordinates Attributes:")
for coord_name in reference.coords:
    print(f"  {coord_name}: {reference[coord_name].attrs}")

print("\nData Variables Attributes:")
for var_name in reference.data_vars:
    print(f"  {var_name}: {reference[var_name].attrs}")
# Out:
# Dataset Attributes:
# {'file_name': 'mesh_hgr.nc', 'TimeStamp': '03/02/2016 10:24:55 -0000', 'DODS_EXTRA.Unlimited_Dimension': 't'}
#
# Coordinates Attributes:
#
# Data Variables Attributes:
#   nav_lon: {}
#   nav_lat: {}
#   nav_lev: {}
#   time_counter: {}
#   glamt: {}
#   glamu: {}
#   glamv: {}
#   glamf: {}
#   gphit: {}
#   gphiu: {}
#   gphiv: {}
#   gphif: {}
#   e1t: {}
#   e1u: {}
#   e1v: {}
#   e1f: {}
#   e2t: {}
#   e2u: {}
#   e2v: {}
#   e2f: {}
#   ff: {}

# %%
reference
# Out:
# <xarray.Dataset> Size: 1GB
# Dimensions:       (y: 3059, x: 4322, z: 50, t: 1)
# Dimensions without coordinates: y, x, z, t
# Data variables: (12/21)
#     nav_lon       (y, x) float32 53MB dask.array<chunksize=(3059, 4322), meta=np.ndarray>
#     nav_lat       (y, x) float32 53MB dask.array<chunksize=(3059, 4322), meta=np.ndarray>
#     nav_lev       (z) float32 200B dask.array<chunksize=(50,), meta=np.ndarray>
#     time_counter  (t) float64 8B dask.array<chunksize=(1,), meta=np.ndarray>
#     glamt         (t, y, x) float32 53MB dask.array<chunksize=(1, 3059, 4322), meta=np.ndarray>
#     glamu         (t, y, x) float32 53MB dask.array<chunksize=(1, 3059, 4322), meta=np.ndarray>
#     ...            ...
#     e1f           (t, y, x) float64 106MB dask.array<chunksize=(1, 3059, 4322), meta=np.ndarray>
#     e2t           (t, y, x) float64 106MB dask.array<chunksize=(1, 3059, 4322), meta=np.ndarray>
# ...

# %%
for k,v in reference.variables.items():
    print(f"{k}")
# Out:
# nav_lon
# nav_lat
# nav_lev
# time_counter
# glamt
# glamu
# glamv
# glamf
# gphit
# gphiu
# gphiv
# gphif
# e1t
# e1u
# e1v
# e1f
# e2t
# e2u
# e2v
# e2f
# ff

# %%
reference
# Out:
# <xarray.Dataset> Size: 1GB
# Dimensions:       (y: 3059, x: 4322, z: 50, t: 1)
# Dimensions without coordinates: y, x, z, t
# Data variables: (12/21)
#     nav_lon       (y, x) float32 53MB dask.array<chunksize=(3059, 4322), meta=np.ndarray>
#     nav_lat       (y, x) float32 53MB dask.array<chunksize=(3059, 4322), meta=np.ndarray>
#     nav_lev       (z) float32 200B dask.array<chunksize=(50,), meta=np.ndarray>
#     time_counter  (t) float64 8B dask.array<chunksize=(1,), meta=np.ndarray>
#     glamt         (t, y, x) float32 53MB dask.array<chunksize=(1, 3059, 4322), meta=np.ndarray>
#     glamu         (t, y, x) float32 53MB dask.array<chunksize=(1, 3059, 4322), meta=np.ndarray>
#     ...            ...
#     e1f           (t, y, x) float64 106MB dask.array<chunksize=(1, 3059, 4322), meta=np.ndarray>
#     e2t           (t, y, x) float64 106MB dask.array<chunksize=(1, 3059, 4322), meta=np.ndarray>
# ...

# %%
import numpy as np
import pandas as pd
import xarray as xr

# Define dimension sizes based on reference dataset
T, Z, Y, X = 1, 50, 3059, 4322

def create_mimick_data() -> xr.Dataset:
    

    return xr.Dataset(
        {
            "nav_lon": (("y", "x"), np.random.rand(Y, X)),
            "nav_lat": (("y", "x"), np.random.rand(Y, X)),
            "nav_lev": (("z",), np.random.rand(Z)),
            "time_counter": (("t",), np.random.rand(T)),
            "glamt": (("t", "y", "x"), np.random.rand(T, Y, X)),
            "glamu": (("t", "y", "x"), np.random.rand(T, Y, X)),
            "glamv": (("t", "y", "x"), np.random.rand(T, Y, X)),
            "glamf": (("t", "y", "x"), np.random.rand(T, Y, X)),
            "gphit": (("t", "y", "x"), np.random.rand(T, Y, X)),
            "gphiu": (("t", "y", "x"), np.random.rand(T, Y, X)),
            "gphiv": (("t", "y", "x"), np.random.rand(T, Y, X)),
            "gphif": (("t", "y", "x"), np.random.rand(T, Y, X)),
            "e1t": (("t", "y", "x"), np.random.rand(T, Y, X)),
            "e1u": (("t", "y", "x"), np.random.rand(T, Y, X)),
            "e1v": (("t", "y", "x"), np.random.rand(T, Y, X)),
            "e1f": (("t", "y", "x"), np.random.rand(T, Y, X)),
            "e2t": (("t", "y", "x"), np.random.rand(T, Y, X)),
            "e2u": (("t", "y", "x"), np.random.rand(T, Y, X)),
            "e2v": (("t", "y", "x"), np.random.rand(T, Y, X)),
            "e2f": (("t", "y", "x"), np.random.rand(T, Y, X)),
            "ff": (("t", "y", "x"), np.random.rand(T, Y, X)),
        },attrs={'file_name': 'mesh_hgr.nc', 'TimeStamp': '03/02/2016 10:24:55 -0000', 'DODS_EXTRA.Unlimited_Dimension': 't'},
        
    )

    
# `reference` should be defined in a previous cell
# Ensure `reference` is loaded before this cell is run.
example = create_mimick_data()
# print("Mimicked Dataset:")
# print(example)
# print("\nMimicked Dataset Attributes:")
# print(example.attrs)

# print("\nReference Dataset for comparison:")
# print(reference)  # Still print reference for manual comparison if needed by the user
# print("\nReference Dataset Attributes:")
# print(repr(reference.attrs))

utils.compare_datasets(example, reference, "Mimicked Dataset", "Reference Dataset")
# Out:
# Comparing Mimicked Dataset and Reference Dataset
#
# Dataset Attributes Comparison:
#   Dataset attributes are identical.
# ------------------------------
# Dimensions Comparison:
#   Dimension names are identical.
#   Dimension 't':
#     Mimicked Dataset size: 1, Reference Dataset size: 1
#   Dimension 'x':
#     Mimicked Dataset size: 4322, Reference Dataset size: 4322
#   Dimension 'z':
#     Mimicked Dataset size: 50, Reference Dataset size: 50
#   Dimension 'y':
#     Mimicked Dataset size: 3059, Reference Dataset size: 3059
# ------------------------------
# Variables Comparison:
#   Variable names are identical.
#   Variable 'gphit':
#     Attributes are identical.
#     Dimensions used are identical: ('t', 'y', 'x')
#   Variable 'e2v':
#     Attributes are identical.
#     Dimensions used are identical: ('t', 'y', 'x')
#   Variable 'e1t':
#     Attributes are identical.
#     Dimensions used are identical: ('t', 'y', 'x')
#   Variable 'glamu':
# ...

# %%
create_mimick_data()
